# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import pickle
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as sw

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_core_interactivity = "all"

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv("https://raw.githubusercontent.com/laxmimerit/twitter-data/master/twitt30k.csv")
data.head()
# 1 -pos, 0- neg
# Out:
#                                               twitts  sentiment
# 0       @robbiebronniman Sounds like a great night.           1
# 1  Damn the person who stolde my wallet !!!!!  Ma...          1
# 2  Greetings from the piano bench  (photo) http:/...          1
# 3  @drewryanscott i love it!! i love you!! haha f...          1
# 4  @kissthestars Pretty pretty pretty please, pak...          0

# %%
#Data Prep
data["sentiment"].value_counts()
# Out:
# 1    15000
# 0    15000
# Name: sentiment, dtype: int64

# %%
data.isna().sum()
# Out:
# twitts       0
# sentiment    0
# dtype: int64

# %%
data[data.duplicated()]  #Same wishes can appear multiple times
# Out:
#                                                   twitts  sentiment
# 4413                                      good morning!           1
# 7654   libertines reunion  i need a haircut, its gone...          1
# 8027                           isPlayer Has Died! Sorry           0
# 8766    cant afford to see Angels and Demons, so i wa...          0
# 11413                                     good morning!           1
# 13322                                    My tummy hurts           0
# 14252                                          headache           0
# 14960                                          Headache           0
# 14996                                          headache           0
# 15000                          isPlayer Has Died! Sorry           0
# 16045                                     my back hurts           0
# 16393                                @reatlas  Clean Me!          0
# 16838                                        Goodnight!           1
# 17511                                      good morning           1
# 17822                                          headache           0
# 19459                                     good morning!           1
# 20069             I am so so so so so bored of studying           0
# 20177                                          headache           0
# 20758                                Happy Mothers Day!           1
# 21351                          isPlayer Has Died! Sorry           0
# 21797                                      good morning           1
# 22041                                        tummy ache           0
# 23200                          isPlayer Has Died! Sorry           0
# 23251  no one is signing up to come talk?  the lighti...          0
# 23990                                      good morning           1
# 24570                                      Good Morning           1
# 24808                                    good morning !           1
# 25638  I am so so so so so bored of studying  REALLY....          0
# 26311                                    misses my kids           0
# 27034  Justwatched the premier of Jon  Kate plus 8 an...          0
# 27202  @nickpaulus Get 100 followers a day using www....          1
# 27338                                          headache           0
# 27485                                     my back hurts           0
# 27912                                          homework           0
# 29133                                         bored now           0

# %%
#Model Training

def SVM(data):
    X = data["twitts"]
    y = data["sentiment"]

    tfidf = TfidfVectorizer()
    X = tfidf.fit_transform(X)

    X_train,X_test,y_train,y_test = train_test_split(X,y,random_state =0,test_size=0.2,stratify = y)

    print(X_train.shape)
    print(X_test.shape)
    print(y_train.shape)
    print(y_test.shape)

    clf = LinearSVC()
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    print(y_pred.shape)
    
    print(classification_report(y_test,y_pred))
    
    return tfidf,clf

# %%
# %%time
tfidf, clf = SVM(data)
# Out:
# (24000, 40854)
# (6000, 40854)
# (24000,)
# (6000,)
# (6000,)
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75      3000
#            1       0.74      0.75      0.75      3000
#
#     accuracy                           0.75      6000
#    macro avg       0.75      0.75      0.75      6000
# weighted avg       0.75      0.75      0.75      6000
#
# Wall time: 3.93 s

# %%
x = ["very very pleasant bro"]
clf.predict(tfidf.transform(x))
# Out:
# array([1], dtype=int64)

# %% [markdown]
# ### Data Cleaning and Retraining

# %%
data.head()
# Out:
#                                               twitts  sentiment
# 0       @robbiebronniman Sounds like a great night.           1
# 1  Damn the person who stolde my wallet !!!!!  Ma...          1
# 2  Greetings from the piano bench  (photo) http:/...          1
# 3  @drewryanscott i love it!! i love you!! haha f...          1
# 4  @kissthestars Pretty pretty pretty please, pak...          0

# %%
#lowercase conversion
data["twitts"] = data["twitts"].apply(lambda x: str(x).lower())

# %%
#Contarction to expansion

contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how does",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
" u ": " you ",
" ur ": " your ",
" n ": " and ",
"won't": "would not",
'dis': 'this',
'bak': 'back',
'brng': 'bring'}

def cont_to_exp(x):
    if type(x) is str:
        for key in contractions:
            value = contractions[key]
            x = x.replace(key, value)
        return x
    else:
        return x


data["twitts"] = data["twitts"].apply(lambda x: cont_to_exp(x))

# %%
data.head()
# Out:
#                                               twitts  sentiment
# 0       @robbiebronniman sounds like a great night.           1
# 1  damn the person who stolde my wallet !!!!!  ma...          1
# 2  greetings from the piano bench  (photo) http:/...          1
# 3  @drewryanscott i love it!! i love you!! haha f...          1
# 4  @kissthestars pretty pretty pretty please, pak...          0

# %%
SVM(data)
# Out:
# (24000, 40846)
# (6000, 40846)
# (24000,)
# (6000,)
# (6000,)
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75      3000
#            1       0.75      0.76      0.75      3000
#
#     accuracy                           0.75      6000
#    macro avg       0.75      0.75      0.75      6000
# weighted avg       0.75      0.75      0.75      6000
# (TfidfVectorizer(), LinearSVC())

# %%
#remove emails
data["twitts"] = data["twitts"].apply(lambda x: re.sub(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)',"",x))

#remove urls
data["twitts"] = data["twitts"].apply(lambda x: re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', '' , x))

#remove rt
data["twitts"] = data["twitts"].apply(lambda x: re.sub('\brt\b','', x).strip())

#remove html tags
data["twitts"] = data["twitts"].apply(lambda x: BeautifulSoup(x,"lxml").get_text().strip())

#remove spcl chars
data["twitts"] = data["twitts"].apply(lambda x: re.sub('[^\w ]+',"", x).strip())

#remove extra spaces
data["twitts"] = data["twitts"].apply(lambda x: " ".join(x.split()))

# %%
#remove accented chars

import unicodedata
def remove_accented_chars(x):
    x = unicodedata.normalize('NFKD', x).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return x

data["twitts"] = data["twitts"].apply(lambda x: remove_accented_chars(x))

# %%
#remove stopwords
data["twitts"] = data["twitts"].apply(lambda x: ' '.join([t for t in x.split() if t not in sw]))

# %%
tfidf,clf = SVM(data)
# Out:
# (24000, 42567)
# (6000, 42567)
# (24000,)
# (6000,)
# (6000,)
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      3000
#            1       0.72      0.73      0.72      3000
#
#     accuracy                           0.72      6000
#    macro avg       0.72      0.72      0.72      6000
# weighted avg       0.72      0.72      0.72      6000

# %%
#Lemma
nlp = spacy.load('en_core_web_sm')
def make_to_base(x):
    x = str(x)
    x_list = []
    doc = nlp(x)
    
    for token in doc:
        lemma = token.lemma_
        if lemma == '-PRON-' or lemma == 'be':
            lemma = token.text

        x_list.append(lemma)
    return ' '.join(x_list)

data["twitts"] = data["twitts"].apply(lambda x: make_to_base(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-f9f63df09522> in <module>
#      14     return ' '.join(x_list)
#      15
# ---> 16 data["twitts"] = data["twitts"].apply(lambda x: make_to_base(x))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-33-f9f63df09522> in <lambda>(x)
#      14     return ' '.join(x_list)
#      15
# ---> 16 data["twitts"] = data["twitts"].apply(lambda x: make_to_base(x))
#
# <ipython-input-33-f9f63df09522> in make_to_base(x)
#       4     x = str(x)
#       5     x_list = []
# ----> 6     doc = nlp(x)
#       7
#       8     for token in doc:
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     429                 Errors.E088.format(length=len(text), max_length=self.max_length)
#     430             )
# --> 431         doc = self.make_doc(text)
#     432         if component_cfg is None:
#     433             component_cfg = {}
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in make_doc(self, text)
#     455
#     456     def make_doc(self, text):
# --> 457         return self.tokenizer(text)
#     458
#     459     def _format_docs_and_golds(self, docs, golds):
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# doc.pyx in spacy.tokens.doc.Doc.__init__()
#
# doc.pyx in spacy.tokens.doc._get_chunker()
#
# ~\Anaconda3\lib\site-packages\spacy\util.py in get_lang_class(lang)
#      69     # Check if language is registered / entry point is available
#      70     if lang in registry.languages:
# ---> 71         return registry.languages.get(lang)
#      72     else:
#      73         try:
#
# ~\Anaconda3\lib\site-packages\catalogue.py in get(self, name)
#      90         """
#      91         if self.entry_points:
# ---> 92             from_entry_point = self.get_entry_point(name)
#      93             if from_entry_point:
#      94                 return from_entry_point
#
# ~\Anaconda3\lib\site-packages\catalogue.py in get_entry_point(self, name, default)
#     136         RETURNS (Any): The loaded entry point or the default value.
#     137         """
# --> 138         for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
#     139             if entry_point.name == name:
#     140                 return entry_point.load()
#
# ~\Anaconda3\lib\site-packages\importlib_metadata\__init__.py in get(self, name, default)
#     310
#     311     def get(self, name, default=None):
# --> 312         flake8_bypass(self._warn)()
#     313         return super().get(name, default)
#     314
#
# ~\Anaconda3\lib\site-packages\importlib_metadata\__init__.py in flake8_bypass(func)
#     271     import inspect
#     272
# --> 273     is_flake8 = any('flake8' in str(frame.filename) for frame in inspect.stack()[:5])
#     274     return func if not is_flake8 else lambda: None
#     275
#
# ~\Anaconda3\lib\inspect.py in stack(context)
#    1511 def stack(context=1):
#    1512     """Return a list of records for the stack above the caller's frame."""
# -> 1513     return getouterframes(sys._getframe(1), context)
#    1514
#    1515 def trace(context=1):
#
# ~\Anaconda3\lib\inspect.py in getouterframes(frame, context)
#    1488     framelist = []
#    1489     while frame:
# -> 1490         frameinfo = (frame,) + getframeinfo(frame, context)
#    1491         framelist.append(FrameInfo(*frameinfo))
#    1492         frame = frame.f_back
#
# ~\Anaconda3\lib\inspect.py in getframeinfo(frame, context)
#    1458         raise TypeError('{!r} is not a frame or traceback object'.format(frame))
#    1459
# -> 1460     filename = getsourcefile(frame) or getfile(frame)
#    1461     if context > 0:
#    1462         start = lineno - 1 - context//2
#
# ~\Anaconda3\lib\inspect.py in getsourcefile(object)
#     691                  importlib.machinery.EXTENSION_SUFFIXES):
#     692         return None
# --> 693     if os.path.exists(filename):
#     694         return filename
#     695     # only return a non-existent filename if the module has a PEP 302 loader
#
# ~\Anaconda3\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
tfidf,clf = SVM(data)
# Out:
# (24000, 42567)
# (6000, 42567)
# (24000,)
# (6000,)
# (6000,)
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      3000
#            1       0.72      0.73      0.72      3000
#
#     accuracy                           0.72      6000
#    macro avg       0.72      0.72      0.72      6000
# weighted avg       0.72      0.72      0.72      6000

# %% [markdown]
# ### Fine Tuning the SVM Model

# %%
#Model Training

def SVM_tuned(data):
    X = data["twitts"]
    y = data["sentiment"]

    tfidf = TfidfVectorizer(norm="l1",ngram_range=(1,2),analyzer = "word",max_features = 7000)
#     (1,5),analyzer = "char"
    X = tfidf.fit_transform(X)

    X_train,X_test,y_train,y_test = train_test_split(X,y,random_state =0,test_size=0.2,stratify = y)

    print(X_train.shape)
    print(X_test.shape)
    print(y_train.shape)
    print(y_test.shape)

    clf = LinearSVC()
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    print(y_pred.shape)
    
    print(classification_report(y_test,y_pred))
    
    return tfidf,clf

# %%
SVM_tuned(data)
# Out:
# (24000, 7000)
# (6000, 7000)
# (24000,)
# (6000,)
# (6000,)
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72      3000
#            1       0.72      0.73      0.72      3000
#
#     accuracy                           0.72      6000
#    macro avg       0.72      0.72      0.72      6000
# weighted avg       0.72      0.72      0.72      6000
# (TfidfVectorizer(max_features=7000, ngram_range=(1, 2), norm='l1'),
#  LinearSVC())

# %% [markdown]
# ### Save and Load Model

# %%
import pickle
pickle.dump(clf,open("model.pkl","wb"))
pickle.dump(tfidf,open("tfidf.pkl","wb"))

# %%
model = pickle.load(open("model.pkl","rb"))
tfidf = pickle.load(open("tfidf.pkl","rb"))

# %%
tfidf.vocabulary_
# Out:
# {'robbiebronniman': 31367,
#  'sounds': 34552,
#  'like': 21673,
#  'great': 15282,
#  'night': 26240,
#  'damn': 9438,
#  'person': 28348,
#  'stolde': 35297,
#  'wallet': 40290,
#  'karma': 19951,
#  'come': 8173,
#  'bite': 4854,
#  'ass': 3258,
#  'greetings': 15333,
#  'piano': 28565,
#  'bench': 4494,
#  'photo': 28523,
#  'drewryanscott': 11128,
#  'love': 22349,
#  'haha': 15673,
#  'forget': 13718,
#  'hugyou': 17111,
#  'kissno': 20527,
#  'lie': 21605,
#  'awesome': 3562,
#  'kissthestars': 20528,
#  'pretty': 29398,
#  'pakidownload': 27766,
#  'ito': 18353,
#  'reupload': 31074,
#  'someother': 34368,
#  'site': 33730,
#  'mediafire': 23681,
#  'hindi': 16589,
#  'mgwork': 24028,
#  'ang': 2577,
#  'mu': 25299,
#  'skin': 33791,
#  'upset': 39513,
#  'lilyroseallen': 21734,
#  'big': 4709,
#  'pool': 29067,
#  'paddling': 27714,
#  'able': 1267,
#  'manage': 22985,
#  'paddle': 27713,
#  'surroundings': 35951,
#  'luxury': 22612,
#  'arianna_skye': 3021,
#  'hee': 16236,
#  'tweet': 38832,
#  'youre': 42283,
#  '10001': 37,
#  'lol': 22125,
#  'happy': 15901,
#  'tickets': 37619,
#  'concerts': 8338,
#  'mileycyrus': 24262,
#  'miley': 24258,
#  'look': 22212,
#  'soooo': 34451,
#  'better': 4620,
#  'laid': 20983,
#  'mustgotobedearly': 25449,
#  'shhhhquitely': 33212,
#  'nowcome': 26665,
#  'found': 13790,
#  'hole': 16715,
#  'fence': 13100,
#  'uh': 39179,
#  'oh': 27006,
#  'sound': 34545,
#  'messed': 23963,
#  'cable': 6328,
#  'festi12s': 13133,
#  'best': 4572,
#  'finally': 13260,
#  'hammock': 15813,
#  'innagual': 17939,
#  'yahooooooooo': 41966,
#  'peace': 28182,
#  'harmony': 15955,
#  'mitchelmusso': 24558,
#  'allowed': 2161,
#  'live': 21928,
#  'uk': 39202,
#  'parents': 27919,
#  'cost': 8687,
#  'sucks': 35636,
#  'sandysaikman': 32127,
#  'makes': 22902,
#  'sad': 31922,
#  'know': 20634,
#  'talk': 36300,
#  'favourite': 12996,
#  'silver': 33599,
#  'hook': 16850,
#  'nutty': 26790,
#  'stock': 35284,
#  'right': 31242,
#  'leaving': 21336,
#  'hell': 16296,
#  'car': 6584,
#  'awfulugh': 3581,
#  'realised': 30420,
#  'ive': 18432,
#  'spent': 34699,
#  'a475': 1111,
#  'clothes': 7903,
#  'today': 37924,
#  'singing': 33667,
#  'duo': 11347,
#  'aussie': 3449,
#  'koala': 20658,
#  'wwwmarcopallicom': 41686,
#  'mahafreed': 22842,
#  'im': 17618,
#  'running': 31785,
#  'battery': 4099,
#  '20': 306,
#  'wont': 41334,
#  'long': 22192,
#  'planning': 28798,
#  'soon': 34432,
#  'daru': 9640,
#  'zidman8': 42492,
#  'nice': 26143,
#  'meeting': 23728,
#  'work': 41404,
#  'minute': 24375,
#  'truejerseygirl': 38621,
#  'went': 40755,
#  'kid': 20365,
#  'scotland': 32487,
#  'north': 26570,
#  'sea': 32586,
#  'catching': 6809,
#  'cod': 8008,
#  'whacking': 40823,
#  'head': 16104,
#  'cried': 8985,
#  'time': 37692,
#  'eat': 11502,
#  'leftover': 21382,
#  'chinese': 7384,
#  'calling': 6423,
#  'ri_guy': 31158,
#  'bad': 3802,
#  'thats': 36919,
#  'happend': 15885,
#  'tara': 36390,
#  'excited': 12546,
#  'sorry': 34513,
#  'getting': 14614,
#  'ready': 30400,
#  'fun': 14141,
#  'day': 9756,
#  'laying': 21255,
#  'sun': 35753,
#  'new': 26036,
#  'schedule': 32412,
#  'kicks': 20363,
#  'sunday': 35773,
#  'edmercer': 11612,
#  'said': 31971,
#  'piaget': 28563,
#  'packing': 27699,
#  'home': 16762,
#  'bostonyay': 5439,
#  'james__buckley': 18593,
#  'hope': 16876,
#  'ouve': 27548,
#  'got': 15129,
#  'suncream': 35768,
#  'coz': 8808,
#  'amanda21crook': 2280,
#  'burnt': 6155,
#  'beach': 4193,
#  'yesterday': 42161,
#  'alroker': 2228,
#  'hi': 16487,
#  'al': 1930,
#  'near': 25849,
#  'lake': 20992,
#  'george': 14559,
#  'ny': 26809,
#  'frost': 14050,
#  'covered': 8784,
#  'flowers': 13523,
#  'veggie': 39768,
#  'plants': 28808,
#  'june': 19706,
#  '1st': 293,
#  'happens': 15892,
#  'moving': 25110,
#  'summer': 35722,
#  'ball': 3877,
#  'amazing': 2317,
#  'feeling': 13060,
#  'death': 9915,
#  'sitting': 33737,
#  'bed': 4317,
#  'cuppa': 9199,
#  'watching': 40423,
#  'office': 26954,
#  'thehurricaneee': 37054,
#  'hot': 16945,
#  'tamale': 36328,
#  'wayknee': 40479,
#  'ahhh': 1774,
#  'vicentemendoza': 39885,
#  'agree': 1735,
#  'ep10': 12151,
#  'heard': 16147,
#  'suicide': 35690,
#  'thingy': 37271,
#  'yi': 42192,
#  'jungga': 19711,
#  'eul': 12362,
#  'tandem': 36349,
#  'soo': 34428,
#  'exhausted': 12574,
#  'feel': 13056,
#  'sick': 33497,
#  'cant': 6537,
#  'anymore': 2808,
#  'princesita015': 29449,
#  'london': 22178,
#  'cities': 7687,
#  'anonyw': 2734,
#  'yea': 42052,
#  'sha': 32940,
#  'nggak': 26104,
#  'di': 10393,
#  'officialin': 26971,
#  'kesel': 20268,
#  'abis': 1260,
#  'left': 21377,
#  'brooklyn': 5864,
#  'bumping': 6102,
#  'sarah': 32161,
#  'white': 40932,
#  'soundz': 34555,
#  'fly': 13552,
#  'don': 10835,
#  'cuco': 9149,
#  'ms': 25217,
#  'blanca': 4950,
#  'goodluck': 15031,
#  'en': 12006,
#  'espana': 12293,
#  'balmainbazaar': 3889,
#  'facehunter': 12745,
#  'embarrassing': 11896,
#  'representation': 30910,
#  'compare': 8257,
#  'swedes': 36064,
#  'born': 5419,
#  'stylish': 35564,
#  'watch': 40415,
#  'saw': 32304,
#  'iv': 18427,
#  'drink': 11146,
#  'lil': 21701,
#  'wine': 41144,
#  'stoshad': 35357,
#  'bought': 5457,
#  'bullpen': 6076,
#  'hat': 15998,
#  'thought': 37504,
#  'douchey': 10965,
#  'possibilities': 29167,
#  'urgh': 39548,
#  'playing': 28841,
#  'game': 14337,
#  'hour': 16978,
#  'computer': 8310,
#  'decided': 9962,
#  'needs': 25883,
#  'restartbefore': 30994,
#  'chance': 7058,
#  'save': 32291,
#  'pdfloral': 28172,
#  'miss': 24428,
#  'having': 16045,
#  'retail': 31028,
#  'store': 35333,
#  'lot': 22305,
#  'loved': 22359,
#  'shop': 33349,
#  'girl': 14746,
#  'stevenleedawson': 35198,
#  'missed': 24458,
#  'vodka': 40075,
#  'food': 13654,
#  'chips': 7409,
#  'milk': 24275,
#  'reading': 30393,
#  'days': 9788,
#  'jackyan': 18527,
#  'good': 15010,
#  'solutions': 34348,
#  'heh': 16252,
#  'hey': 16443,
#  'fam': 12833,
#  'teemwilliams': 36615,
#  'tonight': 38108,
#  'sure': 35917,
#  'feels': 13067,
#  'havent': 16040,
#  'seen': 32696,
#  'perform': 28316,
#  'aggess': 1706,
#  'uploading': 39506,
#  'photos': 28541,
#  'facebook': 12741,
#  'friendster': 14001,
#  'myspace': 25530,
#  'later': 21140,
#  'poor': 29080,
#  'little': 21903,
#  'cold': 8067,
#  'need': 25876,
#  'sleep': 33904,
#  'meet': 23726,
#  'friend': 13979,
#  'hotjane': 16955,
#  'yeah': 42064,
#  'um': 39236,
#  'jane': 18646,
#  'unboring': 39272,
#  'eye': 12689,
#  'candy': 6513,
#  'hon': 16816,
#  'canberra': 6497,
#  'think': 37273,
#  'dance': 9469,
#  'goin': 14960,
#  'sleeping': 33917,
#  'beacose': 4211,
#  'tomorrow': 38064,
#  'sports': 34805,
#  'bngr': 5174,
#  'chesterfield': 7293,
#  'ave': 3507,
#  'main': 22860,
#  'road': 31341,
#  'way': 40475,
#  'heuston': 16438,
#  'gates': 14415,
#  'chilfreebies': 7359,
#  'franchise': 13843,
#  'type': 39094,
#  'business': 6185,
#  'princesammie': 29448,
#  'joined': 19372,
#  'honeymagazine': 16826,
#  'website': 40574,
#  'couldnt': 8721,
#  'find': 13275,
#  'add': 1481,
#  'icaruswingz': 17406,
#  'cunt': 9187,
#  'weeks': 40647,
#  'copy': 8612,
#  'rr': 31695,
#  'wait': 40234,
#  'oops': 27305,
#  'nevermind': 26029,
#  'billboard': 4756,
#  'ericakelly01': 12208,
#  'goodnight': 15040,
#  'dodger': 10752,
#  'burned': 6148,
#  'vanunu': 39722,
#  'yes': 42143,
#  'happened': 15886,
#  'baby': 3717,
#  'howie_d': 17025,
#  'gonna': 15002,
#  'care': 6607,
#  'strong': 35461,
#  'boy': 5497,
#  'attempting': 3370,
#  'hopefully': 16881,
#  'renblink182': 30842,
#  'ok': 27064,
#  'msn': 25262,
#  'bit': 4842,
#  'chippy': 7408,
#  'mo': 24668,
#  'dinner': 10529,
#  'speak': 34651,
#  'laters': 21147,
#  'mishmash878': 24416,
#  'week': 40617,
#  'hand': 15825,
#  'starting': 35046,
#  'yal': 41975,
#  'sophomre': 34492,
#  'kim': 20426,
#  'sang': 32130,
#  'bum': 6084,
#  'tvhaha': 38793,
#  'tynzboompow': 39093,
#  'crazy': 8920,
#  'songs': 34401,
#  'rid': 31222,
#  'recently': 30500,
#  'regret': 30690,
#  'alot': 2200,
#  'davidarchie': 9708,
#  'concert': 8336,
#  'david': 9699,
#  'cook': 8533,
#  'singers': 33664,
#  'physics': 28557,
#  'actually': 1446,
#  'sayin': 32317,
#  'tonyprice': 38145,
#  'job': 19254,
#  '2nyt': 479,
#  'friends': 13990,
#  'luvd': 22598,
#  'pimp': 28647,
#  'dtphulp': 11256,
#  'voice': 40081,
#  'euh': 12361,
#  'finetuning': 13286,
#  'omjitssarax3': 27187,
#  'things': 37264,
#  'ed': 11566,
#  'mcmahon': 23609,
#  'nooo': 26522,
#  'accident': 1343,
#  'airport': 1859,
#  'structural': 35470,
#  'failure': 12784,
#  'called': 6418,
#  'tired': 37793,
#  'fvck': 14226,
#  'didnt': 10447,
#  'slp': 33995,
#  'darthslr': 9639,
#  'gmail': 14881,
#  'working': 41429,
#  'sort': 34517,
#  'broken': 5845,
#  'hp': 17039,
#  'printer': 29467,
#  'couple': 8747,
#  'months': 24884,
#  'currys': 9227,
#  'hmm': 16651,
#  'answer': 2742,
#  'fsdt': 14082,
#  'annouced': 2710,
#  'shit': 33273,
#  'college': 8118,
#  'life': 21617,
#  'laugh': 21162,
#  'mtv': 25295,
#  'hate': 16000,
#  'sleepovers': 33928,
#  'shannon': 33030,
#  'mount': 25059,
#  'zoomer': 42541,
#  'comic': 8195,
#  'tear': 36558,
#  'friendley': 13984,
#  'trying': 38649,
#  'people': 28284,
#  'follow': 13609,
#  'check': 7193,
#  'acemansworldcom': 1379,
#  'cool': 8554,
#  'heading': 16121,
#  'internet': 18059,
#  'jonas_dreamgirl': 19416,
#  'waiting': 40240,
#  'nail': 25644,
#  'polish': 29021,
#  'dry': 11232,
#  'gotta': 15145,
#  'hair': 15737,
#  'makeup': 22904,
#  'xoxo': 41858,
#  'hates': 16012,
#  'babysit': 3732,
#  'bus': 6174,
#  'carlisle': 6646,
#  '11ish': 121,
#  'likely': 21683,
#  'smiths': 34077,
#  'fest': 13132,
#  'sims': 33641,
#  'monday': 24810,
#  'going': 14962,
#  'ground': 15410,
#  'zero': 42480,
#  'dont': 10888,
#  'wanna': 40324,
#  'reasons': 30465,
#  'mmmicaela': 24636,
#  'ha': 15621,
#  'jamescantbeseen': 18597,
#  'imy2': 17730,
#  'sicker': 33499,
#  'thank': 36857,
#  'god': 14925,
#  'nyais': 26812,
#  'operation': 27325,
#  'successful': 35617,
#  'lying': 22634,
#  'sleepy': 33935,
#  'datarock': 9658,
#  'rock': 31433,
#  'painting': 27755,
#  'sexycitymag': 32909,
#  'want': 40331,
#  'anc153': 2498,
#  'luckyyy': 22510,
#  'apparently': 2881,
#  'robeks': 31377,
#  'entire': 12123,
#  'state': 35065,
#  'pa': 27673,
#  'renato71': 30841,
#  'morning': 24971,
#  'nisher': 26352,
#  'heck': 16227,
#  'sastch': 32241,
#  'year': 42085,
#  'bail': 3855,
#  'lack': 20928,
#  'expenses': 12614,
#  'yelyahwilliams': 42129,
#  'hayley': 16066,
#  'yer': 42138,
#  'biggest': 4724,
#  'fan': 12859,
#  'philippines': 28475,
#  'tim339': 37688,
#  'suppose': 35901,
#  'interview': 18081,
#  'true': 38608,
#  'icon': 17437,
#  'karl': 19939,
#  'lagerfeld': 20973,
#  'amazes': 2314,
#  'dancing': 9482,
#  'shoes': 33318,
#  'blistered': 5035,
#  'feet': 13071,
#  'question': 29949,
#  'ut': 39596,
#  'worth': 41496,
#  'hoping': 16891,
#  'old': 27106,
#  'pulls': 29739,
#  'trumps': 38633,
#  'tip': 37782,
#  'capeside': 6561,
#  'inexplicably': 17855,
#  'creeped': 8960,
#  'house': 16988,
#  'scary': 32388,
#  'beautiful': 4264,
#  'oo': 27258,
#  'amused': 2440,
#  'xx': 41897,
#  'ugh': 39163,
#  'ate': 3323,
#  'tummy': 38730,
#  'ache': 1385,
#  'ciaobella6': 7622,
#  'yay': 42024,
#  'loving': 22407,
#  'chicken': 7334,
#  'wings': 41155,
#  'kfc': 20312,
#  'finger': 13289,
#  'lickin': 21596,
#  'asfuwegharegu': 3148,
#  'hangovers': 15855,
#  'algebra': 2048,
#  'final': 13252,
#  'midnight': 24149,
#  'loooooong': 22233,
#  'mention': 23904,
#  'kids': 20383,
#  'school': 32427,
#  'whewwhy': 40891,
#  'kind': 20465,
#  'energy': 12060,
#  'kathryn17': 20006,
#  'ryanj81': 31854,
#  'single': 33668,
#  '3hours': 605,
#  'birds': 4812,
#  'shot': 33382,
#  'officially': 26979,
#  'middle': 24137,
#  'welshdragon72': 40736,
#  'tell': 36657,
#  'jordi': 19493,
#  'chandler': 7061,
#  'described': 10233,
#  'cock': 7990,
#  'warts': 40387,
#  'losing': 22292,
#  'fast': 12943,
#  'justbreathex': 19747,
#  'lian': 21567,
#  'robmader': 31401,
#  'finish': 13297,
#  'bahama': 3850,
#  'breeze': 5664,
#  'perezwill': 28306,
#  'fued': 14116,
#  'xxxx': 41926,
#  'song': 34395,
#  'youll': 42270,
#  'heart': 16154,
#  'phil': 28462,
#  'collins': 8132,
#  'ipod': 18164,
#  'tarzan': 36418,
#  'soundtrack': 34554,
#  'rules': 31765,
#  'xd': 41781,
#  'wondering': 41320,
#  'anybody': 2800,
#  'reads': 30398,
#  'opportunities': 27335,
#  'walk': 40268,
#  'llama': 22009,
#  'calmer': 6432,
#  'uhoh': 39194,
#  'hear': 16146,
#  'oven': 27554,
#  'bell': 4449,
#  'shortcrust': 33371,
#  'pastry': 28014,
#  'dead': 9877,
#  'start': 35040,
#  'vallovetwilight': 39682,
#  'kudos': 20824,
#  'doll': 10803,
#  'miami': 24051,
#  'laughing': 21166,
#  'buddah': 6006,
#  'hanging': 15849,
#  'topher': 38197,
#  'tsk': 38666,
#  'daddy': 9361,
#  'emo': 11968,
#  'hahaha': 15683,
#  'thingsmomslike': 37268,
#  'wow': 41524,
#  'huge': 17092,
#  'prize': 29490,
#  'congrats': 8398,
#  'camp': 6470,
#  'religious': 30772,
#  'nuts': 26784,
#  'wide_receiver': 41011,
#  'rubbish': 31720,
#  'weekend': 40625,
#  'suffering': 35665,
#  'eddiekemp': 11577,
#  'suck': 35623,
#  'following': 13630,
#  'ily': 17611,
#  'sputuk': 34860,
#  'surely': 35920,
#  'audi': 3408,
#  'teehee': 36609,
#  'failedcarmodels': 12777,
#  'chapla1n': 7091,
#  'yugo': 42349,
#  'angiggle': 2619,
#  'early': 11465,
#  'backstreetboys': 3794,
#  'brian': 5705,
#  'youare': 42258,
#  'adorable': 1550,
#  'funny': 14183,
#  'groundctrl': 15412,
#  'jessako': 19040,
#  'finished': 13299,
#  'product': 29525,
#  'missin': 24464,
#  'lauradman': 21188,
#  'laura': 21182,
#  'maybe': 23524,
#  'catch': 6806,
#  'nap': 25711,
#  'ddlovato': 9860,
#  'uklondon': 39209,
#  'fansite': 12882,
#  'knw': 20656,
#  'gna': 14893,
#  'ill': 17569,
#  'shw': 33468,
#  'therealrouga': 37159,
#  'sooooo': 34453,
#  'rouga': 31636,
#  'chillin': 7368,
#  'piece': 28606,
#  'plastic': 28811,
#  'fell': 13086,
#  'iphone': 18153,
#  '3g': 601,
#  'tiny': 37775,
#  'silent': 33580,
#  'button': 6249,
#  'volume': 40096,
#  'buttons': 6250,
#  'lost': 22296,
#  'wanting': 40337,
#  'rollingcherry': 31519,
#  'zugabe': 42549,
#  'gal': 14312,
#  'dat': 9653,
#  'scholarette': 32424,
#  'onthelow': 27251,
#  'hide': 16505,
#  'keys': 20307,
#  'cell': 6953,
#  'phone': 28507,
#  'stay': 35089,
#  'longer': 22196,
#  'princess_han': 29451,
#  'told': 38010,
#  'happening': 15890,
#  'wish': 41199,
#  'thouht': 37514,
#  'sung': 35788,
#  'thisapointed': 37307,
#  'accomplished': 1358,
#  'looking': 22216,
#  'forward': 13774,
#  'flat': 13428,
#  'soulmate': 34539,
#  'vidal': 39911,
#  'sassoon': 32233,
#  'selfish': 32742,
#  'mean': 23647,
#  'daughteri': 9672,
#  'guess': 15495,
#  'grow': 15426,
#  'lisjustice': 21864,
#  'davethinkslisgaynohomo': 9697,
#  'rotflmao': 31629,
#  'bones': 5275,
#  'matthewadamdiaz': 23458,
#  'learn': 21317,
#  'paolakoala': 27856,
#  'miles': 24255,
#  'surrounded': 35949,
#  'steep': 35114,
#  'hills': 16568,
#  'carriemrobison': 6724,
#  'rocks': 31456,
#  'picnic': 28591,
#  'jazz': 18803,
#  'area': 2994,
#  'andysalmon': 2565,
#  'coffee': 8033,
#  'workout': 41447,
#  'inbst': 17756,
#  'mall': 22942,
#  'took': 38156,
#  '45': 670,
#  'mins': 24367,
#  'woke': 41288,
#  'kinda': 20466,
#  'warm': 40362,
#  'sore': 34499,
#  'throat': 37544,
#  'allergies': 2120,
#  'gasp': 14407,
#  'swine': 36124,
#  'maker': 22899,
#  'possible': 29170,
#  'adhd': 1508,
#  'clean': 7802,
#  'fizzyduck': 13387,
#  'suggest': 35683,
#  'music': 25416,
#  'electro': 11770,
#  'project': 29558,
#  'fresh': 13946,
#  'kickin': 20360,
#  'different': 10470,
#  'free': 13902,
#  'dl': 10686,
#  'somethings': 34377,
#  'temporary': 36687,
#  'spaces': 34605,
#  'ebassman': 11521,
#  'yo': 42214,
#  'ya': 41944,
#  'feverishpoptart': 13145,
#  'costing': 8691,
#  '1000': 32,
#  'instead': 18008,
#  '300': 502,
#  'anticipated': 2766,
#  'plane': 28785,
#  'buenos': 6025,
#  'aires': 1852,
#  'apple': 2897,
#  'bobbibillard': 5193,
#  'large': 21093,
#  'number': 26748,
#  '14': 189,
#  'aneshaisaplus': 2573,
#  'creative': 8941,
#  'wut': 41640,
#  'uuuuuu': 39625,
#  'thang': 36853,
#  'helbro': 16279,
#  'hicke': 16497,
#  'os': 27438,
#  '30': 501,
#  'available': 3496,
#  '18th': 244,
#  '0100': 3,
#  'local': 22071,
#  '1pm': 291,
#  '17th': 236,
#  'york': 42246,
#  '1900': 246,
#  'central': 6977,
#  'europe': 12372,
#  'techcommdood': 36576,
#  'er': 12186,
#  'cup': 9190,
#  'amandacool': 2285,
#  'beans': 4233,
#  'cacheshantel': 6336,
#  'exams': 12521,
#  'gaaaah': 14259,
#  'fair': 12790,
#  'surprisingly': 35943,
#  'ashleytisdale': 3192,
#  'album': 1966,
#  'listened': 21872,
#  'preview': 29410,
#  'fact': 12754,
#  'spell': 34685,
#  'ridiculous': 31232,
#  'prove': 29638,
#  'texting': 36804,
#  'super': 35842,
#  'bored': 5392,
#  'text': 36797,
#  'carscarscarsi': 6735,
#  'wanted': 40332,
#  'sold': 34324,
#  'aidan': 1814,
#  'nooooooooooooooooo': 26537,
#  'diversity': 10598,
#  'julian': 19666,
#  'win': 41127,
#  'susan': 35963,
#  'i12i12': 17309,
#  'maggie': 22813,
#  'turbolisa': 38751,
#  'hnbzbjhhbxbzjsjjshshann': 16670,
#  'replied': 30897,
#  'misskellyo': 24475,
#  'eyes': 12705,
#  'cooking': 8545,
#  'onions': 27225,
#  'chest': 7290,
#  'infection': 17863,
#  'huh': 17113,
#  'kuja': 20828,
#  'zidane': 42490,
#  'womanizing': 41306,
#  'idiot': 17462,
#  'run': 31778,
#  'status': 35084,
#  'update': 39484,
#  'twitter': 38977,
#  'ice': 17411,
#  'timestamp': 37726,
#  'mon': 24803,
#  'jun': 19705,
#  '15': 203,
#  '134640': 185,
#  'cest': 7003,
#  '2009': 317,
#  'goes': 14951,
#  'bump': 6098,
#  'nascar': 25739,
#  'truckseries': 38605,
#  'shows': 33427,
#  'gabflat': 14275,
#  'katy': 20052,
#  'perry': 28341,
#  'supposed': 35902,
#  'suchbut': 35621,
#  'works': 41452,
#  'elaineellis': 11742,
#  'intense': 18032,
#  'sushi': 35971,
#  'plate': 28813,
#  'blueinkstains': 5128,
#  'odnt': 26922,
#  'absinthe': 1294,
#  'breastfed': 5649,
#  'babies': 3712,
#  'erin82883': 12237,
#  'wouldnt': 41513,
#  'norafayerberg': 26550,
#  'blakeeligh': 4945,
#  'cbc': 6874,
#  'crying': 9089,
#  'flaimster': 13404,
#  'falls': 12829,
#  '10': 30,
#  'rollerskating': 31516,
#  'ahh': 1767,
#  'hurts': 17219,
#  'phase': 28451,
#  'kimba': 20428,
#  'worse': 41490,
#  'juneninth': 19709,
#  'exactly': 12506,
#  'mrchrisp': 25152,
#  'whats': 40849,
#  'chris': 7487,
#  'omg': 27157,
#  'd00d': 9330,
#  'spelling': 34690,
#  'phish': 28493,
#  'thechelseastaub': 36990,
#  'toolol': 38160,
#  'moments': 24776,
#  'till': 37683,
#  'jtshea': 19608,
#  'remember': 30804,
#  'episodethat': 12170,
#  'depressive': 10206,
#  'futurama': 14211,
#  'episode': 12168,
#  'ashamed': 3151,
#  'course': 8753,
#  'tweets': 38868,
#  'oakland': 26830,
#  'tonightyay': 38123,
#  'oaktown': 26832,
#  'girls': 14765,
#  'rye': 31874,
#  'selenajoey': 32734,
#  'cute': 9254,
#  'joey': 19316,
#  'plezzzzzzzzzz': 28883,
#  'ctz': 9135,
#  'stop': 35323,
#  'pax': 28126,
#  'mvshaw': 25470,
#  'currently': 9224,
#  'unemployed': 39328,
#  'frantically': 13867,
#  'searching': 32614,
#  'applied': 2913,
#  'places': 28777,
#  'luck': 22492,
#  'ideas': 17451,
#  'nashvegas': 25744,
#  'jetblue': 19106,
#  'munchies': 25373,
#  'mix': 24564,
#  'flight': 13467,
#  'fortydeucetwits': 13769,
#  'kuz': 20852,
#  'looked': 22213,
#  'won': 41313,
#  'reserved': 30949,
#  'dina': 10516,
#  'shalabhchaudhri': 32989,
#  'btw': 5971,
#  'socializing': 34260,
#  'easy': 11498,
#  'achievement': 1392,
#  'master': 23375,
#  'gato_anesama': 14419,
#  'hurt': 17212,
#  'feelings': 13062,
#  'situation': 33739,
#  'chelisamontique': 7240,
#  'tradeshowthispla': 38351,
#  'form': 13737,
#  'julieallinson': 19676,
#  'hb': 16081,
#  ...}
